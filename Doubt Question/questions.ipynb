# %%
from xml.etree.ElementPath import xpath_tokenizer
do we have any precedence in this 8 locators maam? i case we have all the locators , which we give 1st preferance . anything like that maam?

i tried macy's , tried to inspect women's section, i can see the text is within span tag. this span tag is within anchor tag. how do we inspect in this case maam?

so when we come across the text part with space, we use partial link text? is it irrespective to tag, or only anchor tag maam?

during relative xpath what shoukd we do if the attribute is having multiple count?

value attribute in html is meant for storing the users input in real time apps maam?

after providing input for search bar via send keys, how do we perform enter operation maam? for jio mart, when i run the code , it is simply halting and in the drop down it is suggesting the products

when we say hidden , it means the element is present but is in a different web page? and can be accessed only when in tht page?

in other words , we dont have to mention index value when we use independent-dependant xpath concept?

Got to recorded classes >> menu Select the batch Choose the date submit


what is xpath?

how do you write xpath?

what is synchronization?

what is coftest?

what is fetch dynamic data?  dependaent - independent xpath

is repository a virtual memory?

how will the internal structure of the repository look like? because ever changes made will be recorded separately. am i right?

so we will be storing every changes in seoarate repository every time?
